# %% [markdown]
# Import modules.

# %%
import pandas as pd
import os
import glob
import re
import csv
import numpy as np
from functools import reduce

# %% [markdown]
# Two snippets below: first is for the 4th Draft folder, second is for the 5th Draft folder. We use the latter for the analysis below hence the former is commented out.

# %%
# path = r"C:\Users\ddimov\Documents\HospitalsBlueprintLocal\4th Draft"
# all_files = glob.glob(path + "/*.csv")
# li = []

# for filename in all_files:
#     df = pd.read_csv(filename)
#     df["DoorType"] = df.Name.str.split("-").str[0]
#     li.append(df)

# frame = pd.concat(li, axis=0, ignore_index=True)
# frame.to_csv("fourthDraftDoors.csv")

# %% [markdown]
# Sorting all columns in alphabetical order also included below.

# %%
path = r"C:\Users\ddimov\Documents\HospitalsBlueprintLocal\5th Draft"
all_files = glob.glob(path + "/*.csv")

output_file = pd.concat([pd.read_csv(filename) for filename in all_files]).fillna(0)
output_file = output_file.rename(columns = {'Unnamed: 0':'AUniqueID'})
output_file = output_file.reindex(sorted(output_file.columns),axis=1)

output_file.to_csv("fifthDraftDoors.csv")

# %%
output_file
# Out:
#                 AUniqueID Access Control Accessories & Sundry Items  \
# 0   IfcText('PTH0027.D1')   IfcText('-')                          0
# 1   IfcText('PTH0030.D1')   IfcText('-')             IfcText('TBC')
# 2   IfcText('MOR0014.D1')   IfcText('-')                          0
# 3   IfcText('MOR0023.D1')   IfcText('-')                          0
# 4   IfcText('MOR0022.D2')   IfcText('-')                          0
# ..                    ...            ...                        ...
# 69  IfcText('CCU2004.D1')   IfcText('-')                          0
# 70  IfcText('CCU2003.D1')   IfcText('-')                          0
# 71  IfcText('CCU2127.D1')   IfcText('-')                          0
# 72  IfcText('CCU2095.D1')   IfcText('-')                          0
# 73  IfcText('CCU2095.D3')   IfcText('-')                          0
#
#    Acoustic Designation Acoustic Rating Appear In Schedule Assembly Code  \
# 0           IfcText('')               0                  0   IfcText('')
# 1       IfcText('30dB')               0                  0   IfcText('')
# 2                     0               0                  0   IfcText('')
# 3       IfcText('30dB')               0                  0   IfcText('')
# 4       IfcText('30dB')               0                  0   IfcText('')
# ..                  ...             ...                ...           ...
# 69                    0               0                  0   IfcText('')
# 70                    0               0                  0   IfcText('')
# 71                    0               0                  0   IfcText('')
# 72                    0               0                  0   IfcText('')
# 73                    0               0                  0   IfcText('')
#
#    Assembly Description AssetIdentifier   Blind Type  ...       Type Mark URL  \
# 0           IfcText('')               0  IfcText('')  ...  IfcText('J35')   0
# 1           IfcText('')               0  IfcText('')  ...  IfcText('J58')   0
# 2           IfcText('')               0  IfcText('')  ...  IfcText('J35')   0
# 3           IfcText('')               0  IfcText('')  ...  IfcText('J35')   0
# 4           IfcText('')               0  IfcText('')  ...  IfcText('J35')   0
# ..                  ...             ...          ...  ...             ...  ..
# 69          IfcText('')               0  IfcText('')  ...  IfcText('J55')   0
# 70          IfcText('')               0  IfcText('')  ...  IfcText('J55')   0
# 71          IfcText('')               0  IfcText('')  ...  IfcText('J52')   0
# 72          IfcText('')               0  IfcText('')  ...  IfcText('J55')   0
# 73          IfcText('')               0            0  ...  IfcText('J55')   0
#
#        Vision Panel Visual Light Transmittance WarrantyDescription  \
# 0                 0                          0                   0
# 1   IfcBoolean(.F.)                          0                   0
# 2                 0                          0                   0
# 3                 0                          0                   0
# 4                 0                          0                   0
# ..              ...                        ...                 ...
# 69                0                          0                   0
# 70                0                          0                   0
# 71                0                          0                   0
# 72                0                          0                   0
# 73                0                          0                   0
#
#    WarrantyDurationLabour WarrantyDurationParts WarrantyGuarantorLabour  \
# 0                       0                     0                       0
# 1                       0                     0                       0
# 2                       0                     0                       0
# 3                       0                     0                       0
# 4                       0                     0                       0
# ..                    ...                   ...                     ...
# 69                      0                     0                       0
# 70                      0                     0                       0
# 71                      0                     0                       0
# 72                      0                     0                       0
# 73                      0                     0                       0
#
#    WarrantyGuarantorParts                    Width
# 0                       0  IfcLengthMeasure(1060.)
# 1                       0  IfcLengthMeasure(1510.)
# 2                       0  IfcLengthMeasure(1060.)
# 3                       0  IfcLengthMeasure(1060.)
# 4                       0  IfcLengthMeasure(1060.)
# ..                    ...                      ...
# 69                      0   IfcLengthMeasure(810.)
# 70                      0   IfcLengthMeasure(810.)
# 71                      0  IfcLengthMeasure(1060.)
# 72                      0   IfcLengthMeasure(810.)
# 73                      0   IfcLengthMeasure(810.)
#
# [2489 rows x 191 columns]

# %% [markdown]
# Two functions below to clean the aggregated table with all doors exported from the ifc model.

# %%
for column in output_file:
    output_file[column] = output_file[column].astype(str).str.extract(r"\((.*)\)", expand=True)
    output_file[column] = output_file[column].astype(str).str.replace('\'','')
    
df_obj = output_file.select_dtypes(['string'])
output_file[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())  
#data = data.astype(str).split('(')[1].lstrip().rstrip('\)')
output_file.to_csv("fifthDraftDoors.csv")

# %%
output_file
# Out:
#      AUniqueID Access Control Accessories & Sundry Items Acoustic Designation  \
# 0   PTH0027.D1              -                        nan
# 1   PTH0030.D1              -                        TBC                 30dB
# 2   MOR0014.D1              -                        nan                  nan
# 3   MOR0023.D1              -                        nan                 30dB
# 4   MOR0022.D2              -                        nan                 30dB
# ..         ...            ...                        ...                  ...
# 69  CCU2004.D1              -                        nan                  nan
# 70  CCU2003.D1              -                        nan                  nan
# 71  CCU2127.D1              -                        nan                  nan
# 72  CCU2095.D1              -                        nan                  nan
# 73  CCU2095.D3              -                        nan                  nan
#
#    Acoustic Rating Appear In Schedule Assembly Code Assembly Description  \
# 0              nan                nan
# 1              nan                nan
# 2              nan                nan
# 3              nan                nan
# 4              nan                nan
# ..             ...                ...           ...                  ...
# 69             nan                nan
# 70             nan                nan
# 71             nan                nan
# 72             nan                nan
# 73             nan                nan
#
#    AssetIdentifier Blind Type  ... Type Mark  URL Vision Panel  \
# 0              nan             ...       J35  nan          nan
# 1              nan             ...       J58  nan          .F.
# 2              nan             ...       J35  nan          nan
# 3              nan             ...       J35  nan          nan
# 4              nan             ...       J35  nan          nan
# ..             ...        ...  ...       ...  ...          ...
# 69             nan             ...       J55  nan          nan
# 70             nan             ...       J55  nan          nan
# 71             nan             ...       J52  nan          nan
# 72             nan             ...       J55  nan          nan
# 73             nan        nan  ...       J55  nan          nan
#
#    Visual Light Transmittance WarrantyDescription WarrantyDurationLabour  \
# 0                         nan                 nan                    nan
# 1                         nan                 nan                    nan
# 2                         nan                 nan                    nan
# 3                         nan                 nan                    nan
# 4                         nan                 nan                    nan
# ..                        ...                 ...                    ...
# 69                        nan                 nan                    nan
# 70                        nan                 nan                    nan
# 71                        nan                 nan                    nan
# 72                        nan                 nan                    nan
# 73                        nan                 nan                    nan
#
#    WarrantyDurationParts WarrantyGuarantorLabour WarrantyGuarantorParts  Width
# 0                    nan                     nan                    nan  1060.
# 1                    nan                     nan                    nan  1510.
# 2                    nan                     nan                    nan  1060.
# 3                    nan                     nan                    nan  1060.
# 4                    nan                     nan                    nan  1060.
# ..                   ...                     ...                    ...    ...
# 69                   nan                     nan                    nan   810.
# 70                   nan                     nan                    nan   810.
# 71                   nan                     nan                    nan  1060.
# 72                   nan                     nan                    nan   810.
# 73                   nan                     nan                    nan   810.
#
# [2489 rows x 191 columns]

# %% [markdown]
# The functions below are 1) to find an example of non-null value and 2) to count the Percent Completeness for each column.

# %%
# col_names = list(output_file.columns)

# # non_null_list = list()
# # def funca(x):
# #     if x.first_valid_index() is None:
# #         non_null_list.append("Null")
# #     else:
# #         non_null_list.append(x[x.first_valid_index()])
# # output_file.apply(funca, axis=0)
 
# completeness_list = list()
# def funcb(y):
#     s = ((1-(y.isnull().sum())/len(y)))
#     completeness_list.append(s)
# output_file.apply(funcb, axis=0)

# newdata = pd.DataFrame({"ColumnName": col_names, 
# #                         "ExampleData" : non_null_list,
#                         "Completeness": completeness_list})

# newdata.to_csv("Doors Model Ouput Columns Analysis.csv")

# %% [markdown]
# Mapping function:

# %%
def mapColumn(masterDictionary, masterCol, newColName, keY):
    
    dictLoc = dict(masterDictionary[[masterCol, newColName]].values)
    
    output_file["Mapped " + newColName] = output_file[keY].map(dictLoc)

# %% [markdown]
# Pulling data from the tabulated Door Schedules (excel files) - first for the main tables and then for Set Refs (Ironmongery Sets)

# %%
os.chdir(r"C:\Users\ddimov\Documents\HospitalsBlueprintLocal")
masterInternal = pd.read_excel("SCCC_Internal_Door_Schedules.xlsx",sheet_name="CombinedLevelsInternal")
masterExternal = pd.read_excel("SCCC_External_Door_Schedules.xlsx",sheet_name="CombinedLevelsExternal")

setRefsInternal = pd.read_excel("SCCC_Internal_Door_Schedules.xlsx", sheet_name="SetRefsInternal")
setRefsExternal = pd.read_excel("SCCC_External_Door_Schedules.xlsx", sheet_name="SetRefsExternal")


masterDoorSchedules = pd.concat([masterInternal,masterExternal]).fillna(0)
masterDoorSchedules = masterDoorSchedules.rename(columns = {'MasterMark':'AbUniqueID'})
masterDoorSchedules = masterDoorSchedules.reindex(sorted(masterDoorSchedules.columns),axis=1)

# for column in masterDoorSchedules:
#     masterDoorSchedules[column] = masterDoorSchedules[column].astype(str).str.replace(' ','')

masterDoorSetRefs = pd.concat([setRefsExternal,setRefsInternal]).fillna(0)
masterDoorSetRefs = masterDoorSetRefs.reindex(sorted(masterDoorSetRefs.columns), axis=1)

# for column in masterDoorSetRefs:
#     masterDoorSetRefs[column] = masterDoorSetRefs[column].astype(str).str.replace(' ','')

masterDoorSchedules.to_csv("Door Schedules Combined (External and Internal).csv")
masterDoorSetRefs.to_csv("Door Schedules Set Refs Combined (Ext and Int).csv")

# %% [markdown]
# Pulling data from the paragraphs Door Schedules - had to manually export them into txt files and the aggregate them into one single dataframe.

# %%
l20431DoorSchedule = pd.read_csv("L20431DoorSchedule.txt",names = ['Property','L20_431_Details'],skiprows =1, sep=':')
l20432DoorSchedule = pd.read_csv("L20432DoorSchedule.txt",names = ['Property','L20_432_Details'],skiprows =1, sep=':')
l20433DoorSchedule = pd.read_csv("L20433DoorSchedule.txt",names = ['Property','L20_433_Details'],skiprows =1, sep=':')
l20434DoorSchedule = pd.read_csv("L20434DoorSchedule.txt",names = ['Property','L20_434_Details'],skiprows =1, sep=':')
l20435DoorSchedule = pd.read_csv("L20435DoorSchedule.txt",names = ['Property','L20_435_Details'],skiprows =1, sep=':')
l20439DoorSchedule = pd.read_csv("L20439DoorSchedule.txt",names = ['Property','L20_439_Details'],skiprows =1, sep=':')

pdf_door_schedules = [df.set_index("Property") for df in [l20431DoorSchedule,l20432DoorSchedule,
                                l20433DoorSchedule,l20434DoorSchedule,
                               l20435DoorSchedule,l20439DoorSchedule]]

pdf_door_schedules = reduce(lambda l,r: l.combine_first(r), pdf_door_schedules)

# %%
mapColumn(masterDoorSchedules, "AbUniqueID", "Ironmongery Set", "AUniqueID" )

# %%
pdf_door_schedules
# Out:
#                                                                                       L20_431_Details  \
# Property
# Appearance class to BS EN 942                                                                     NaN
# As clause 431 but door leaf to incorporate lead...                                                NaN
# Beading                                                                                As clause 184.
# Clear glazing to suit fire and safety performan...                                                NaN
# Clear glazing with integral blinds IBT 01, 02 o...                                                NaN
# Description                                                                                       NaN
# Door leaf Core                                                                                    NaN
# Door leaf Edge protection                                                                         NaN
# Door leaf Facings                                                                                 NaN
# Door leaf Finish as delivered                                                                     NaN
# Door leaf Frame and architraves                                                                   NaN
# Door leaf Lippings                                                                                NaN
# Door leaf core                                       Flaxboard with softwood or hardwood timber st...
# Door leaf facings                                    Formica high pressure plastic laminate finish...
# Door leaf lippings                                   Ash, concealed; arrisses require 3mm radius; ...
# Duty                                                                                     Severe duty.
# Edge protection                                      Grade 304 stainless steel angle protection to...
# Either Solid hardwood primed for site painting.                                                   NaN
# Finish as delivered                                  Self finish to laminate and clear hard wearin...
# Finish as delivered                                  Self finish to laminate and clear hard wearin...
# Finish as delivered                                  Self finish to PVC wrapping; matching PVC flu...
# Finish as delivered                                  Self finish to PVC wrapping; matching PVC flu...
# Fire resistance rating                               Refer to the Door and Ironmongery Schedule. T...
# Fixing                                               Plugged and screwed as section Z20 with frame...
# Frame and architraves                                                                    as scheduled
# Frame and architraves Appearance class to BS EN...                 Quality class to J10 to BS EN 942.
# Frame and architraves Finish as delivered                                                         NaN
# Frame and architraves Wood species                               Hardwood to BS EN 942 as table NA2 .
# Frame and architraves finish as delivered            Primed for site painting as Section M60. Or P...
# Frame profile                                        Equivalent to Leaderflush Shapland Laidlaw 'B...
# Glazing                                              Clear glazing to suit fire and safety perform...
# Glazing                                              Clear glazing to suit fire and safety perform...
# Glazing                                              Clear glazing with integral blinds IBT 01 as ...
# Glazing                                              Clear glazing with integral blinds IBT 01 as ...
# Glazing/ Infill details                              Refer to the Door Schedule and Internal Door ...
# Hinges to be selected to suit additional weight.                                                  NaN
# Ironmongery                                                                  As ironmongery schedule.
# Lead to be integrated within the door construct...                                                NaN
# Manifestation                                                                                     NaN
# Manufacturer                                         Leaderflush Shapland Laidlaw or an approved e...
# Moisture content on delivery                                                                   9-13%.
# Other requirements                                   Doorsets to rooms with gas suppression to mee...
# Perimeter seals                                      Fire and smoke seal to meet the fire and acou...
# Preservative treatment                               Organic solvent as section Z12 and WPA Commod...
# Product                                                   'Designer Range' or an approved equivalent.
# Radiation resistance to be confirmed. Door Sche...                                                NaN
# Security rating                                                                                   NaN
# Sound insulation rating                              Refer to the Acoustic Report and the Door Sch...
# Wood species                                                                                      NaN
# all with clear finished ash beads.                                                                NaN
#
#                                                                                       L20_432_Details  \
# Property
# Appearance class to BS EN 942                                    [Quality class to J10 to BS EN 942].
# As clause 431 but door leaf to incorporate lead...                                                NaN
# Beading                                                                                           NaN
# Clear glazing to suit fire and safety performan...                                                NaN
# Clear glazing with integral blinds IBT 01, 02 o...                                                NaN
# Description                                                                                       NaN
# Door leaf Core                                                                                    NaN
# Door leaf Edge protection                                                                         NaN
# Door leaf Facings                                                                                 NaN
# Door leaf Finish as delivered                                                                     NaN
# Door leaf Frame and architraves                                                                   NaN
# Door leaf Lippings                                                                                NaN
# Door leaf core                                                                                    NaN
# Door leaf facings                                                                                 NaN
# Door leaf lippings                                                                                NaN
# Duty                                                                                              NaN
# Edge protection                                                                                   NaN
# Either Solid hardwood primed for site painting.                                                   NaN
# Finish as delivered                                  [Primed for site painting as Section M60]. Or...
# Finish as delivered                                  Self finish to PVC wrapping; matching PVC flu...
# Finish as delivered                                  [Primed for site painting as Section M60]. Or...
# Finish as delivered                                  Self finish to PVC wrapping; matching PVC flu...
# Fire resistance rating                                                                            NaN
# Fixing                                                                                            NaN
# Frame and architraves                                as scheduled, both lead-lined to maintain rad...
# Frame and architraves Appearance class to BS EN...                                                NaN
# Frame and architraves Finish as delivered                                                         NaN
# Frame and architraves Wood species                                                                NaN
# Frame and architraves finish as delivered                                                         NaN
# Frame profile                                                                                     NaN
# Glazing                                              Lead glass to suit protection level required ...
# Glazing                                              Lead glass to suit protection level required ...
# Glazing                                              Lead glass to suit protection level required ...
# Glazing                                              Lead glass to suit protection level required ...
# Glazing/ Infill details                                                                           NaN
# Hinges to be selected to suit additional weight.                                                  NaN
# Ironmongery                                                                                       NaN
# Lead to be integrated within the door construct...                                                NaN
# Manifestation                                                                                     NaN
# Manufacturer                                                                                      NaN
# Moisture content on delivery                                                                      NaN
# Other requirements                                                                                NaN
# Perimeter seals                                                                                   NaN
# Preservative treatment                                                                            NaN
# Product                                                                                           NaN
# Radiation resistance to be confirmed. Door Sche...                                                NaN
# Security rating                                                                                   NaN
# Sound insulation rating                                                                           NaN
# Wood species                                                    [Hardwood to BS EN 942 as table NA2].
# all with clear finished ash beads.                                                                NaN
#
#                                                                                       L20_433_Details  \
# Property
# Appearance class to BS EN 942                                                                     NaN
# As clause 431 but door leaf to incorporate lead...                                                NaN
# Beading                                                                                As clause 184.
# Clear glazing to suit fire and safety performan...                                                NaN
# Clear glazing with integral blinds IBT 01, 02 o...                                                NaN
# Description                                          Doors by Joinery contractor to be fitted into...
# Door leaf Core                                                                                    NaN
# Door leaf Edge protection                            Grade 304 stainless steel angle protection to...
# Door leaf Facings                                    [Formica high pressure plastic laminate finis...
# Door leaf Finish as delivered                        [Self finish to laminate and clear hard weari...
# Door leaf Frame and architraves                      Extruded aluminium-framed glazed screen as cl...
# Door leaf Lippings                                   [Ash, concealed; arrisses require 3mm radius;...
# Door leaf core                                       [Flaxboard with softwood or hardwood timber s...
# Door leaf facings                                                                                 NaN
# Door leaf lippings                                                                                NaN
# Duty                                                                                     Severe duty.
# Edge protection                                                                                   NaN
# Either Solid hardwood primed for site painting.                                                   NaN
# Finish as delivered                                                                               NaN
# Finish as delivered                                                                               NaN
# Finish as delivered                                                                               NaN
# Finish as delivered                                                                               NaN
# Fire resistance rating                                                               Not applicable..
# Fixing                                                                                            NaN
# Frame and architraves                                                                             NaN
# Frame and architraves Appearance class to BS EN...                                                NaN
# Frame and architraves Finish as delivered                                                         NaN
# Frame and architraves Wood species                                                                NaN
# Frame and architraves finish as delivered                                                         NaN
# Frame profile                                                                                     NaN
# Glazing                                              Clear glazing to suit safety performance requ...
# Glazing                                              Clear glazing with integral blinds IBT 07 or ...
# Glazing                                              Clear glazing to suit safety performance requ...
# Glazing                                              Clear glazing with integral blinds IBT 07 or ...
# Glazing/ Infill details                              Refer to the Door Schedule and Internal Door ...
# Hinges to be selected to suit additional weight.                                                  NaN
# Ironmongery                                                                  As ironmongery schedule.
# Lead to be integrated within the door construct...                                                NaN
# Manifestation                                                                                     NaN
# Manufacturer                                         Leaderflush Shapland Laidlaw or an approved e...
# Moisture content on delivery                                                                   9-13%.
# Other requirements                                                                                NaN
# Perimeter seals                                      Acoustic seals as required to meet the acoust...
# Preservative treatment                                                                            NaN
# Product                                                   'Designer Range' or an approved equivalent.
# Radiation resistance to be confirmed. Door Sche...                                                NaN
# Security rating                                                                                   NaN
# Sound insulation rating                              Refer to the Acoustic Report and the Door Sch...
# Wood species                                                                                      NaN
# all with clear finished ash beads.                                                                NaN
#
#                                                                                       L20_434_Details  \
# Property
# Appearance class to BS EN 942                                      Quality class to J10 to BS EN 942.
# As clause 431 but door leaf to incorporate lead...                                                NaN
# Beading                                              High security stainless steel beads with no e...
# Clear glazing to suit fire and safety performan...                                                NaN
# Clear glazing with integral blinds IBT 01, 02 o...                                                NaN
# Description                                                                                       NaN
# Door leaf Core                                                                                    NaN
# Door leaf Edge protection                                                                         NaN
# Door leaf Facings                                    Plywood facings over 1mm thick Zintec steel s...
# Door leaf Finish as delivered                        Self finish to laminate and clear hard wearin...
# Door leaf Frame and architraves                                                                   NaN
# Door leaf Lippings                                   Ash; arrisses require 3mm radius; minimum thi...
# Door leaf core                                                         Solid laminated hardwood core.
# Door leaf facings                                                                                 NaN
# Door leaf lippings                                                                                NaN
# Duty                                                                                     Severe duty.
# Edge protection                                                                                   NaN
# Either Solid hardwood primed for site painting.                                                   NaN
# Finish as delivered                                         Primed for site painting as Section M60 .
# Finish as delivered                                         Primed for site painting as Section M60 .
# Finish as delivered                                         Primed for site painting as Section M60 .
# Finish as delivered                                         Primed for site painting as Section M60 .
# Fire resistance rating                               Refer to the Door and Ironmongery Schedule. T...
# Fixing                                               In accordance with the manufacturer's high se...
# Frame and architraves                                                                 Solid hardwood.
# Frame and architraves Appearance class to BS EN...                                                NaN
# Frame and architraves Finish as delivered                                                         NaN
# Frame and architraves Wood species                                                                NaN
# Frame and architraves finish as delivered                                                         NaN
# Frame profile                                        Equivalent to Leaderflush Shapland Laidlaw 'M...
# Glazing                                                                                           NaN
# Glazing                                                                                           NaN
# Glazing                                                                                           NaN
# Glazing                                                                                           NaN
# Glazing/ Infill details                              Clear laminated anti-bandit security glazing;...
# Hinges to be selected to suit additional weight.                                                  NaN
# Ironmongery                                                                  As ironmongery schedule.
# Lead to be integrated within the door construct...                                                NaN
# Manifestation                                                           Refer to the Tender Drawings.
# Manufacturer                                         Leaderflush Shapland Laidlaw or an approved e...
# Moisture content on delivery                                                                   9-13%.
# Other requirements                                                                                NaN
# Perimeter seals                                      Fire and smoke seal to meet the fire and acou...
# Preservative treatment                               Organic solvent as section Z12 and WPA Commod...
# Product                                              Extended Performance Castle AV2 Range' or an ...
# Radiation resistance to be confirmed. Door Sche...                                                NaN
# Security rating                                      Leaderflush Shapland Laidlaw delayed entry le...
# Sound insulation rating                              Refer to the Acoustic Report and the Door Sch...
# Wood species                                         Hardwood to BS EN 942 as table NA2; minimum d...
# all with clear finished ash beads.                                                                NaN
#
#                                                                                       L20_435_Details  \
# Property
# Appearance class to BS EN 942                                                                     NaN
# As clause 431 but door leaf to incorporate lead...                                                NaN
# Beading                                                                                As clause 184.
# Clear glazing to suit fire and safety performan...                                                NaN
# Clear glazing with integral blinds IBT 01, 02 o...                                                NaN
# Description                                                                                       NaN
# Door leaf Core                                       Flaxboard with softwood or hardwood timber st...
# Door leaf Edge protection                                                                         NaN
# Door leaf Facings                                    Impact resistant Hygieniform anti-bacterial s...
# Door leaf Finish as delivered                                                                     NaN
# Door leaf Frame and architraves                                                                   NaN
# Door leaf Lippings                                         Hardwood concealed behind post-formed pvc.
# Door leaf core                                                                                    NaN
# Door leaf facings                                                                                 NaN
# Door leaf lippings                                                                                NaN
# Duty                                                                                      Severe duty
# Edge protection                                                                                   NaN
# Either Solid hardwood primed for site painting.                                                   NaN
# Finish as delivered                                                               Self finish to pvc.
# Finish as delivered                                                               Self finish to pvc.
# Finish as delivered                                                               Self finish to pvc.
# Finish as delivered                                                               Self finish to pvc.
# Fire resistance rating                               Refer to the Door and Ironmongery Schedule. T...
# Fixing                                               Plugged and screwed as section Z20 with frame...
# Frame and architraves                                MDF (emission level as clause 185) or hardwoo...
# Frame and architraves Appearance class to BS EN...                                    Not applicable.
# Frame and architraves Finish as delivered            PVC-wrapped as clause 709; matching PVC flush...
# Frame and architraves Wood species                                 Hardwood to manufacturer's choice.
# Frame and architraves finish as delivered                                                         NaN
# Frame profile                                        Equivalent to Leaderflush Shapland Laidlaw 'B...
# Glazing                                                                                           NaN
# Glazing                                                                                           NaN
# Glazing                                                                                           NaN
# Glazing                                                                                           NaN
# Glazing/ Infill details                              Refer to the Door Schedule and Internal Door ...
# Hinges to be selected to suit additional weight.                                                  NaN
# Ironmongery                                                                  As ironmongery schedule.
# Lead to be integrated within the door construct...                                                NaN
# Manifestation                                                           Refer to the Tender Drawings.
# Manufacturer                                         Leaderflush Shapland Laidlaw or an approved e...
# Moisture content on delivery                                                                   9-13%.
# Other requirements                                                                                NaN
# Perimeter seals                                      Fire and smoke seal to meet the fire and acou...
# Preservative treatment                               Organic solvent as section Z12 and WPA Commod...
# Product                                                      'Hygieniform' or an approved equivalent.
# Radiation resistance to be confirmed. Door Sche...                                                NaN
# Security rating                                                                                   NaN
# Sound insulation rating                              Refer to the Acoustic Report and the Door Sch...
# Wood species                                                                                      NaN
# all with clear finished ash beads.                                                                NaN
#
#                                                                                       L20_439_Details
# Property
# Appearance class to BS EN 942                                                                     NaN
# As clause 431 but door leaf to incorporate lead...                                                NaN
# Beading                                                                                           NaN
# Clear glazing to suit fire and safety performan...                                                NaN
# Clear glazing with integral blinds IBT 01, 02 o...                                                NaN
# Description                                                                                       NaN
# Door leaf Core                                                                                    NaN
# Door leaf Edge protection                                                                         NaN
# Door leaf Facings                                                                                 NaN
# Door leaf Finish as delivered                         Primed for site painting as Section M60. Colour
# Door leaf Frame and architraves                                                                   NaN
# Door leaf Lippings                                                                                NaN
# Door leaf core                                       Leaderflush Shapland Laidlaw Simcor solid chi...
# Door leaf facings                                                                                 NaN
# Door leaf lippings                                                                                NaN
# Duty                                                                                     Severe duty.
# Edge protection                                                                                   NaN
# Either Solid hardwood primed for site painting.                                                   NaN
# Finish as delivered                                   Primed for site painting as Section M60. Colour
# Finish as delivered                                   Primed for site painting as Section M60. Colour
# Finish as delivered                                   Primed for site painting as Section M60. Colour
# Finish as delivered                                   Primed for site painting as Section M60. Colour
# Fire resistance rating                               Refer to the Door and Ironmongery Schedule. T...
# Fixing                                               Plugged and screwed as section Z20 with frame...
# Frame and architraves                                             MDF (emission level as clause 185).
# Frame and architraves Appearance class to BS EN...                                                NaN
# Frame and architraves Finish as delivered                                                         NaN
# Frame and architraves Wood species                                                                NaN
# Frame and architraves finish as delivered                                                         NaN
# Frame profile                                        Equivalent to Leaderflush Shapland Laidlaw 'B...
# Glazing                                                                                           NaN
# Glazing                                                                                           NaN
# Glazing                                                                                           NaN
# Glazing                                                                                           NaN
# Glazing/ Infill details                                                                         None.
# Hinges to be selected to suit additional weight.                                                  NaN
# Ironmongery                                                                  As ironmongery schedule.
# Lead to be integrated within the door construct...                                                NaN
# Manifestation                                                                                     NaN
# Manufacturer                                         Leaderflush Shapland Laidlaw or an approved e...
# Moisture content on delivery                                                                   9-13%.
# Other requirements                                   Doorsets to rooms with gas suppression to mee...
# Perimeter seals                                      Fire and smoke seal to meet the fire and acou...
# Preservative treatment                                                                          None.
# Product                                                   'Designer Range' or an approved equivalent.
# Radiation resistance to be confirmed. Door Sche...                                                NaN
# Security rating                                                                                   NaN
# Sound insulation rating                              Refer to the Acoustic Report and the Door Sch...
# Wood species                                                                                      NaN
# all with clear finished ash beads.                                                                NaN

# %%
col_list = masterDoorSchedules.columns.values.tolist()

for column in col_list:
    mapColumn(masterDoorSchedules, "AbUniqueID", column, "AUniqueID" )

# %%
masterDoorSetRefs["Set ref"].unique()
# Out:
# array(['E1a', 'E1b', 'E1c', 'E1d', 'E1e', 'E1f', 'E2', 'E3a', 'E3b',
#        'E3c', 'E4a', 'E4b', 'E4c', 'E5a', 'E5b', 'E5c', 'E5d', 'E6a',
#        'E6b', 'E7', 'E8', 1, '01*', '01FP', '01aFP', 2, '02FP', '02a',
#        '02aFP', 3, '03FP', '03DA', '03DAFP', '03b', '03bFP', '03g',
#        '03gFP', '03c', '03dDA', '03e', '03f', 4, '04FP', '04a', '04b*',
#        '04b', 5, '05DA', '05FP', '05a', '05a*', '05aDA', '05aDA*', '05b',
#        '05bDA', '05c', '05cDA', '05cDA+', '05d', 6, '06a', '06b', '06bFP',
#        '06bGLA', '06c', '06d', '06FP', 7, '07a', '07b', 8, '08DA',
#        '08*DA', '08FP', '08b', '08b*', '08c', '08d', '08dDA', '08e',
#        '08f', '08fDA', '08g', '08h', '08jDA', '08k', '08l', '08m', '08n',
#        '08DAFP', '08p', '08q', 9, '09a', '09b', '09c', 11, '11*', '11DA',
#        '11FP', '11DAFP', '11aFP', '11b', '11b*', '11bFP', '11c', '11d',
#        '11dFP', '11d*', '11dDA', '11eDA', '11fDA', '11gDA', '11hDA',
#        '11j', '11k', '11l', '11m', '11n', '11p', '11q', '11r', '11s',
#        '11t', '11u', '11u*FP', '11v', 12, '12*', '12*FP', '12FP', '12aFP',
#        '12b', '12bFP', '12c', '12d', '12e', '12e*', '12f', '12g', '13a',
#        '13a+', '13b', '13c', '13c+', 16, '16GLA', '16a', '16b', 17, '17a',
#        '17aFP', '17b', '17b*', '17bFP', '17c', '17e', '17f', '17g', '17h',
#        '17j', '17k', 18, 19, '19FP', '19a', '19b', '19c', '19c+', '20a',
#        21, '21DA', '21*DA', '21DAGLA', '21FP', '21a', '21aGLA', '21aFP',
#        '21aDA', '21bDA', '21b', '21bFP', '21bFPDA', '21c', '21cDA',
#        '21dDA', '21eDA', '21fDA', '21gDA', 22, '22FP', '22a', '22aFP',
#        '22b', '22b*', '22bFPDA', '22c', '22d', '22e', '24a', '24b', '24c',
#        '26a', '26b', 28, 29, '29DA', '29DAFP', '29a', '29aDA', '29aDAFP',
#        '29aFP', '29bDA', '30a', 31, '31a', '31FP', 32, 33, '33FP', '33a',
#        '33a*', '33aFP', '33b', '33bFP', '33c', '33cFP', '33d', '33e',
#        '33f', '33g', '33h', 35, 40, 41, 42, '42a', 43, '43a', 44, 45, 46,
#        47, 48, 49], dtype=object)

# %%
col_list_ironmongery = masterDoorSetRefs.columns.values.tolist()

for column in col_list_ironmongery:
    mapColumn(masterDoorSetRefs, "Set ref", column, "Mapped Ironmongery Set")

# %%
output_file.to_csv("fifthDraftDoorsMapped.csv")

# %%
masterDoorSchedules["Leaf Finish"].unique()
# Out:
# array(['Laminate', 0, 'Painted Finish', 'Leaf Finish', 'Powdercoated',
#        'PVC Wrapped'], dtype=object)

# %%
output_file["Keynote"].unique()
# Out:
# array(['L20/431', 'L20', 'L20/512', 'L20/434', 'L20/481', 'H11/136A',
#        'L20/482', 'H11/134A', 'L10/652', 'L20/ 488', 'L11/579', 'L20/439',
#        'L11/579A', 'L10/651', 'H11/138A', 'L20/491', '', 'L20/486',
#        'Q40A/436', 'L20/432', 'L20/484', 'L11/581', 'L20/435', 'L20/436',
#        'L20/433', 'L11/431', '08 34 13', 'nan', 'L20/521', 'L20/616',
#        'L20/ 487'], dtype=object)

# %%
output_file["Specification Reference"].nunique()
# Out:
# 2

# %%
output_fileCopy = output_file

# %%
s_p_1 = output_fileCopy[["Ironmongery Set", "Mapped Ironmongery Set"]]

# %%
s_p_1.reset_index(drop=True, inplace=True)

def RepresentsInt(s):
    try: 
        int(s)
        return True
    except ValueError:
        return False

for i in range(0, len(s_p_1)):
    
    if RepresentsInt(s_p_1.loc[i, ['Ironmongery Set']]):
        s_p_1.loc[i,['Ironmongery Set']]=(int(s_p_1.loc[i,['Ironmongery Set']]))  
        
    if RepresentsInt(s_p_1.loc[i,["Mapped Ironmongery Set"]]):
        s_p_1.loc[i,['Mapped Ironmongery Set']]=(int(s_p_1.loc[i,['Mapped Ironmongery Set']]))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-18-ec589b57f543>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s_p_1.loc[i,['Ironmongery Set']]=(int(s_p_1.loc[i,['Ironmongery Set']]))
# <ipython-input-18-ec589b57f543>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s_p_1.loc[i,['Mapped Ironmongery Set']]=(int(s_p_1.loc[i,['Mapped Ironmongery Set']]))

# %%
##################################################################################################################

# %%
s_p_1["Comparison"] = s_p_1["Mapped Ironmongery Set"].isin(s_p_1["Ironmongery Set"])
# Out:
# <ipython-input-19-bd50804740af>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s_p_1["Comparison"] = s_p_1["Mapped Ironmongery Set"].isin(s_p_1["Ironmongery Set"])

# %%
s_p_1.Comparison.value_counts()
# Out:
# True     2332
# False     157
# Name: Comparison, dtype: int64

# %%
s_p_1.to_csv("s_p_1.csv")

# %%
output_fileCopy.columns
# Out:
# Index(['AUniqueID', 'Access Control', 'Accessories & Sundry Items',
#        'Acoustic Designation', 'Acoustic Rating', 'Appear In Schedule',
#        'Assembly Code', 'Assembly Description', 'AssetIdentifier',
#        'Blind Type',
#        ...
#        'Mapped Mid-rail', 'Mapped Mid‐rail', 'Mapped PowerCloserDelay',
#        'Mapped PullOrLever', 'Mapped Set ref', 'Mapped SetDetails',
#        'Mapped SlaveLeafBolted', 'Mapped Swing', 'Mapped TypicalUses',
#        'Mapped Xray'],
#       dtype='object', length=239)

# %%
output_fileCopy["Fire Designation"].unique()
# Out:
# array(['nan', '', 'FD30S', 'FD60S', 'N/A'], dtype=object)

# %%
output_fileCopy["Fire Rating"].unique()
# Out:
# array(['nan', 'FD60', 'N/A', ''], dtype=object)

# %%
output_fileCopy["Access Control"].unique()
# Out:
# array(['-', '', 'nan', 'Yes', 'TBC', 'No', 'Interlink'], dtype=object)

# %%
ou
